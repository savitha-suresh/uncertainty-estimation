# %% [markdown]
# ### Download Libraries

# %%
import torch
from matplotlib import pyplot as plt
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.datasets import make_swiss_roll
from torch.utils.data import DataLoader, TensorDataset
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from typing import Tuple
import seaborn as sns
from tqdm import trange




print("pyTorch Available:", torch.cuda.is_available())
print("CUDA Device Count:", torch.cuda.device_count())
print("CUDA Current Device:", torch.cuda.current_device())
print("CUDA Device Name:", torch.cuda.get_device_name(0))
     

print("pyTorch Version: ", torch.__version__)
print("pyTorch CUDA Version: ", torch.version.cuda)
#torch.cuda.set_device(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# pyTorch Available: True
# CUDA Device Count: 1
# CUDA Current Device: 0
# CUDA Device Name: NVIDIA GeForce RTX 4050 Laptop GPU
# pyTorch Version:  2.5.1
# pyTorch CUDA Version:  12.1
# cuda

# %% [markdown]
# ### Generate Datasets: Spiral Dataset, Half Moon Dataset & SwissRoll Dataset

# %%
def generate_spiral_data(n_points=1000, noise_std=0.1):
    theta = np.linspace(0, 4 * np.pi, n_points) 
    r = np.linspace(0, 1, n_points) 
    x = r * np.sin(theta) + noise_std * np.random.randn(n_points) 
    y = r * np.cos(theta) + noise_std * np.random.randn(n_points)  
    return np.stack((x, y), axis=-1)

spiral_data = generate_spiral_data()

# Plot
plt.figure(figsize=(6, 6))
plt.scatter(spiral_data[:, 0], spiral_data[:, 1], s=1, color="crimson", alpha=0.6)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Spiral Data")
plt.axis("equal")
plt.show()

# %%
def generate_half_moon(n_samples=5000, noise=0.1):
    X,_= make_moons(n_samples=n_samples, noise=noise)
    return np.stack((X[:, 0], X[:, 1]), axis=-1)

half_moon_data = generate_half_moon()

plt.figure(figsize=(6, 6))
plt.scatter(half_moon_data[:, 0], half_moon_data[:, 1], s=1, c="crimson", alpha=0.6)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Half-Moon Dataset")
plt.axis("equal")
plt.show()

# %%
def generate_swiss_roll(n_samples=2000, noise=0.1):
    X, t = make_swiss_roll(n_samples=n_samples, noise=noise)
    return np.stack((X[:, 0], X[:, 1], X[:, 2]), axis=-1),t

swiss_roll_dataset,t = generate_swiss_roll()

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection="3d")
ax.scatter(swiss_roll_dataset[:, 0], swiss_roll_dataset[:, 1], swiss_roll_dataset[:, 2], c=t, cmap="viridis", s=5)
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.set_title("Swiss Roll Dataset")
plt.show()
print(t)
# Out:
# [14.00262827  8.12447964 11.40093577 ...  6.55937732 13.11653822
#   6.86070607]

# %% [markdown]
# ### Forward Process : Adding Noise

# %%
# class ForwardProcess:
#     def __init__(self, betas: torch.Tensor):
#         self.beta = betas
#         self.alphas = 1. - betas
#         self.alpha_bar = torch.cumprod(self.alphas, dim=-1)


#     def get_x_t(self, x_0: torch.Tensor, t: torch.LongTensor) -> Tuple[torch.Tensor, torch.Tensor]:
#         print(x_0.type)
#         eps_0 = torch.randn_like(x_0)
#         alpha_bar = self.alpha_bar[t, None]
#         mean = (alpha_bar ** 0.5) * x_0
#         std = ((1. - alpha_bar) ** 0.5)
#         x_t = mean + std * eps_0
#         return eps_0, x_t

# %% [markdown]
# #### Testing the forward noise

# %%
# spiral_data_tensor = torch.tensor(spiral_data, dtype=torch.float32)

# %%
# T = 100  # Number of diffusion steps
# betas = torch.linspace(0.0, 0.99, T + 1) ** 4
# fp = ForwardProcess(betas=betas)
# BOUNDS = (-1.5, 1.5)
# for i in range(1):
#     x_batch = next(iter(dataloader))[0]
#     break

# x_batch.shape

# %%
# fig, ax = plt.subplots(1, 4, figsize=(15, 5))
# x_t = spiral_data_tensor[:100].clone()
# for idx, t in enumerate([0, T//4, T//2,T]):
#     x_t = fp.get_x_t(spiral_data_tensor[:100], t=torch.LongTensor([t]))[1].numpy()
#     sns.scatterplot(x=x_t[:, 0], y=x_t[:, 1], ax=ax[idx])
#     ax[idx].set(xlim=BOUNDS, ylim=BOUNDS, title=f"t={t}", aspect="equal")

# %% [markdown]
# ### Define Diffusion Model

# %%
class DiffusionModel(nn.Module):
    def __init__(self, T, input_dim=2, hidden_dim=100, output_dim=2):
        super(DiffusionModel, self).__init__()
        self.T = T
        self.t_embedding = nn.Embedding(T, hidden_dim)

        self.model = nn.Sequential(
            nn.Linear(input_dim + hidden_dim, hidden_dim),  # x_t and time embedding as input
            nn.LeakyReLU(inplace=True),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(inplace=True),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(inplace=True),
            nn.Linear(hidden_dim, 20),
            nn.LeakyReLU(inplace=True),
            nn.Linear(20, output_dim)  # Output predicted noise
        )

    def forward(self, x, t):
        t_emb = self.t_embedding(t)
        
        inp = torch.cat([x, t_emb], dim=1)
        
        return self.model(inp)

# %% [markdown]
# ### Training Diffusion Model for Spiral Data

# %%
spiral_data_tensor = torch.tensor(spiral_data, dtype=torch.float32)
dataset = TensorDataset(spiral_data_tensor)
dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

# %%
timesteps = 100 
epochs = 100
def linear_schedule(timesteps):
    beta_start = 1e-4
    beta_end = 0.02
    return torch.linspace(beta_start, beta_end, timesteps)

betas = linear_schedule(timesteps)
alphas = 1 - betas
alphas_cumprod = torch.cumprod(alphas, dim=0)

# %%
model = DiffusionModel(T=timesteps).to(device)
optimizer = torch.optim.AdamW(params=model.parameters(), lr=1e-4)

# %%
for epoch in range(epochs):
    for batch in dataloader:
        data = batch[0].to(device)

        optimizer.zero_grad()
        loss = 0.0
        batch_size = data.shape[0]

        
        for t in range(timesteps):
            noise = torch.randn_like(data).to(device)
            sqrt_alpha_cumprod_t = torch.sqrt(alphas_cumprod[t]).to(device)
            sqrt_one_minus_alpha_cumprod_t = torch.sqrt(1 - alphas_cumprod[t]).to(device)

            # Add noise
            noisy_data = sqrt_alpha_cumprod_t * data + sqrt_one_minus_alpha_cumprod_t * noise

            # Predict the noise
            t_tensor = torch.tensor([t] * batch_size, device=device)  # Pass timestep t
            predicted_noise = model(noisy_data, t_tensor)

            
            loss += nn.MSELoss()(predicted_noise, noise)

        loss = loss / timesteps  # Average loss over timesteps
        loss.backward()
        optimizer.step()


    print(f"Epoch [{epoch}/{epochs}], Loss: {loss.item():.4f}")
# Out:
# Epoch [0/100], Loss: 0.9257
# Epoch [1/100], Loss: 0.8782
# Epoch [2/100], Loss: 0.7756
# Epoch [3/100], Loss: 0.7053
# Epoch [4/100], Loss: 0.6701
# Epoch [5/100], Loss: 0.5837
# Epoch [6/100], Loss: 0.5494
# Epoch [7/100], Loss: 0.5156
# Epoch [8/100], Loss: 0.4912
# Epoch [9/100], Loss: 0.4841
# Epoch [10/100], Loss: 0.5068
# Epoch [11/100], Loss: 0.4927
# Epoch [12/100], Loss: 0.4350
# Epoch [13/100], Loss: 0.4580
# Epoch [14/100], Loss: 0.4306
# Epoch [15/100], Loss: 0.4981
# Epoch [16/100], Loss: 0.4778
# Epoch [17/100], Loss: 0.4765
# Epoch [18/100], Loss: 0.4958
# Epoch [19/100], Loss: 0.4566
# Epoch [20/100], Loss: 0.4771
# Epoch [21/100], Loss: 0.4952
# Epoch [22/100], Loss: 0.4547
# Epoch [23/100], Loss: 0.4786
# Epoch [24/100], Loss: 0.4810
# Epoch [25/100], Loss: 0.4520
# Epoch [26/100], Loss: 0.4998
# Epoch [27/100], Loss: 0.4406
# Epoch [28/100], Loss: 0.4878
# Epoch [29/100], Loss: 0.4726
# Epoch [30/100], Loss: 0.4987
# Epoch [31/100], Loss: 0.4172
# ...

# %% [markdown]
# ### Reverse Process

# %%
def generate_new_data(model, timesteps, alphas, alphas_cumprod, n_samples=500):
    model.eval()
    with torch.no_grad():
        x_t = torch.randn(n_samples, 2, device = device)

        for t in reversed(range(timesteps)):
            t_tensor = torch.tensor([t] * n_samples, device=device)
            predicted_noise = model(x_t, t_tensor)

            beta_t = betas[t]
            if t > 0:
                alpha_t_minus_one = alphas_cumprod[t-1]
                alpha_t = alphas_cumprod[t]
                sigma_t = torch.sqrt(beta_t*(1-alpha_t_minus_one)/(1-alpha_t))
            else:
                sigma_t = torch.sqrt(betas[0])

            noise = torch.randn_like(x_t, device = device)
            mean = (1 / torch.sqrt(alphas[t])) * (x_t - (betas[t] / torch.sqrt(1 - alphas_cumprod[t])) * predicted_noise)
            x_t = mean + sigma_t * noise

    return x_t

# %%
generated_data = generate_new_data(model, timesteps, alphas, alphas_cumprod, n_samples=1000).cpu()
generated_data
# Out:
# tensor([[ 0.0269, -0.4170],
#         [-0.0167,  0.2117],
#         [ 0.2833,  0.1543],
#         ...,
#         [ 0.4888,  0.3788],
#         [ 0.1180,  0.2494],
#         [ 0.1335, -0.3543]])

# %%
#plt.scatter(spiral_data[:, 0], spiral_data[:, 1], s=5, label="Original Spiral Data")
plt.scatter(generated_data[:, 0].numpy(), generated_data[:, 1].numpy(), s=5, color='red', label="Generated Data")
plt.title("Original vs Generated Spiral Data")
plt.legend()
plt.show()
